# %% [markdown]
# # My Jupyter Notebook

# %% [markdown]
# # Acheampong Yaw Fosu
# # Data Science

# %% [markdown]
# ### I am interested in Data Science because I want to gain insights from data.

# %% [markdown]
# ### This code shows how to print hello world.

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# # .
# # .
# # .
